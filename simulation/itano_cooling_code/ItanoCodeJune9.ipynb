# %% [markdown]
# # The code below is configured for 1-dimensional detuning variation

# %%
# %matplotlib inline
#Adopted from MATLAB code by Charles Xu.
#Steven B. Torrisi Summer 2015

import numpy as np
import scipy as sp
import scipy.optimize as opt
import scipy.integrate as integ
import matplotlib.pyplot as plt
from scipy.constants import pi
plt.rcParams['font.size'] = 16

#Standard parameters and other constants
hbar=1.054E-34;
c=2.9979E8;
lambd=313.112E-9;   #transition wavelength

k=2*pi/lambd;       #Be+ laser wavenumber; assuming offset dw is sufficiently 
                    #small that the shift in the wave number due to dw/(2*pi) can be neglected

kB=1.38E-23;        #Boltzmann's constant
m=8.96*1.673E-27;   # Be+ ion mass

#Input parameters
lowest_df = -150.0E6;     #lowest (most red) detuning of laser beam from atomic 
                          #transition frequency; in Hz; negative numbers correspond to red detuning.
highest_df = -1.0E6;      #highest tuning of the laser beam frequency
incr = 4.0E6;             #increment to be used in going from lowest frequency tuning to highest.
                          #If increment greater than highest-lowest, then only the lowest
                          #frequency detuning will be evaluated
N = int(round((highest_df-lowest_df)/incr));
df = np.linspace(lowest_df,highest_df,N) #Go from lowest df to highest in N steps
                                         #(interpolates linearly)
dw = 2*pi*df;
d = 40.00E-6;               #offset of laser beam from the center of the array in meters, 
                    #positive offsets corresponds to miving the laser beam to the side of 
                    #the cloud (or array) that is receding from the laser beam direction
WR = 2*pi*45.0E3;           #angular rotation frequency in s^{-1}
RP = 225.0E-6;              #radius of ion array in meters


R_bar=(hbar*k)**2/(2*m);    #recoil energy
T = 20.0E-3               #initial guess in temperature in Kelvin

global GAMMA, VK, RNORM, U0, RP, WR, WY, d, S0, SIG
#Define Globals
RNORM=R_bar/(hbar*k);      #A reduced recoil energy
GAMMA=2*pi*18.0E6;         #natural linewidth
VK=GAMMA/(2*k);            # Reduced line width
U0=np.sqrt(2*kB*T/m);      #initial thermal velocity used in Boltzmann factor 
WY=30.0E-6                 #beam width in meters
SIG=2.77E9                 # density at origin
S0=.786                    # Saturation parameter

def density(x,y):
    """
    Defines a density scaling which returns 0 outside of the circular bounds of the crystal.
    Useful because it allows for rectangular integration bounds (i.e. [-r,r])
    instead of complicated functional bounds which are difficult to work with.
    """
    global RP
    rad=x**2+y**2
    if rad<=(RP**2):
        return np.sqrt(1-(rad)/RP**2)
    else:
        return 0

def dEnosaturation(u,detun,offset=d):
    global GAMMA, VK, RNORM,  U0, RP, WR, WY, counter
        
    delta = 2.*detun/GAMMA;
    ret = integ.tplquad(lambda y,x,v:\
                        density(x,y)\
                        *np.exp(-(y-offset)**2 /WY**2) *\
                        ((v)+2*RNORM/u)*np.exp(-v**2)/\
                        (1+(delta-(WR*y/VK)-(u*v/VK))**2),\
                        -np.inf, np.inf,\
                        lambda x: -1*RP, lambda x: RP,\
                        lambda x,y: -1*RP, lambda x,y: RP)
    
    #print("Integral Evaluated",ret[0],"with temperature",u**2*8.96*1.673E-27/(2*1.38E-23))
    counter+=1
    return ret[0]

def dEcomplete(u,detun,offset=d):
    global GAMMA, VK, RNORM,  U0, RP, WR, WY, S0, counter
    delta = 2.*detun/GAMMA;
    ret = integ.tplquad(lambda y,x,v:\
                        density(x,y)\
                        *np.exp(-(y-offset)**2 /WY**2) *\
                        ((v)+2*RNORM/u)*np.exp(-v**2)/\
                        ((1+2*S0*np.exp(-2*(y-d)**2 /WY**2)\
                          +(delta-(WR*y/VK)-(u*v/VK))**2)),\
                        -np.inf, np.inf,\
                        lambda x: -1*RP, lambda x: RP,\
                        lambda x,y: -1*RP, lambda x,y: RP)
    
    #print("Integral Evaluated",ret[0],"with temperature",u**2*8.96*1.673E-27/(2*1.38E-23))
    counter+=1
    return ret[0]

def totalscatter(ueq,detun):

    global GAMMA, VK, RNORM, U0, RP, WR, WY, d,S0,SIG
    delta = 2.*detun/GAMMA;
    constants= GAMMA*S0*SIG*ueq/np.sqrt(np.pi)
    ret = integ.tplquad(lambda y,x,v:\
                        \
                        density(x,y)\
                        *np.exp(-2*(y-d)**2 /WY**2) *\
                        np.exp(-v**2)/\
                        (1+2*S0*np.exp(-2*(y-d)**2 /WY**2)+\
                        (delta-(WR*y/VK)-(ueq*v/VK))**2),\
                        \
                        -np.inf, np.inf,\
                        lambda x: -1*RP, lambda x: RP,\
                        lambda x,y: -1*RP, lambda x,y: RP)
    
    return ret[0]*constants

def totaltorque(ueq,detun):
    global GAMMA, VK, RNORM, U0, RP, WR, WY, d,S0,SIG
    delta = 2.*detun/GAMMA;
    constants= (hbar*k)*GAMMA*S0*SIG*ueq/np.sqrt(np.pi)
    ret = integ.tplquad(lambda v,x,y:\
                        \
                        density(x,y)\
                        *np.exp(-2*(y-d)**2 /WY**2)*y*\
                        np.exp(-v**2)/\
                        (1+2*S0*np.exp(-2*(y-d)**2 /WY**2)+\
                        (delta-(WR*y/VK)-(ueq*v/VK))**2),\
                        \
                        -1*RP, RP,\
                        lambda x: -1*RP, lambda x: RP,\
                        lambda x,y: -1*np.inf, lambda x,y: np.inf,\
                        epsabs=1.49e-10, epsrel=1.49e-10)    
    
    return ret[0]*constants

def getroot(detoffset):
    global GAMMA, VK, RNORM, U0, RP, WR, WY, d,S0,SIG
    print("Trying detuning",detoffset[0]," and offset ",detoffset[1])
    return (opt.brentq(dEver3,umin,umax,args=(detoffset[0],detoffset[1]),xtol=1e-6, rtol=3.0e-8))**2*m/(2*kB)

def getrootdetun(detun):
    global GAMMA, VK, RNORM, U0, RP, WR, WY, d,S0,SIG
    print("Trying detuning",detun)
    return (opt.brentq(dEver3,umin,umax,args=(detun,3.98794261e-05),xtol=1e-6, rtol=3.0e-8))**2*m/(2*kB)
#########################################
U=[0] * (N)
Sc=[0] * (N)
To=[0]*(N)

Tmax=1.0E-1
Tmin=1.0E-5
umax=np.sqrt(Tmax*kB*2/m)
umin=np.sqrt(Tmin*kB*2/m)
global counter
counter=0
print("Beginning...")

#opt.fmin(getroot,[-50.0E6,15.0E-6],args=(detun))
#print(opt.minimize(getroot,[-50.0E6,50.0E-6],method='TNC',bounds=[[-160.0E6,-1.0E6],[0,220.0E-6]]))

#print(opt.minimize(getrootdetun,[-10.0E6] ,method='TNC',bounds=[[-150.0E6,-5.0E6]]))
#return
d=20.0E-06
"""
The following for loop is currently configured to conduct a parameter scan of the 

"""
for R in range(N):
    print("-------------")
    print("Feeding in detuning",dw[R]/(2*3.14159), R+1, "of", range(N)[-1]+1, "Evaluations")
    try:
        U[R]=opt.brentq(dEcomplete,umin,umax,args=(dw[R]),xtol=1e-4, rtol=3.0e-7)
    except:
        try: 
            U[R]=opt.brentq(dEcomplete,umin*.1,umax*10,args=(dw[R]),xtol=1e-4, rtol=3.0e-7)
        except:
            U[R]=opt.brentq(dEcomplete,umin*.01,umax*100,args=(dw[R]),xtol=1e-4, rtol=3.0e-7)
    print("u/T recorded:",U[R],((U[R])*U[R]*8.96*1.673E-27/(2*1.38E-23)),"after",counter,"integral calls.")
    Sc[R]=totalscatter(U[R],dw[R])
    To[R]=totaltorque(U[R],dw[R])
    counter=0

    
#plt.figure(figsize=(12, 10))
Teq=[x**2*m/(2*kB) for x in U];
#b=plt.plot(df,Teq)
#b=plt.xlabel('laser freq. detuning (Hz)')
#b=plt.ylabel('equilibrium temp (K)')
#b=plt.title('Plot of the Equilibrium Temperature')
plt.figure(figsize=(12, 10))
print(Teq)
print(min(Teq))

a=plt.plot(df,Teq)
a=plt.xlabel('laser freq. detuning (Hz)')
a=plt.ylabel('equilibrium temp (K)')
a=plt.title('Plot of the Equilibrium Temperature')
a=plt.yscale('log', nonposy='clip')

plt.figure(figsize=(12, 10))
c=plt.plot(df,Sc)
c=plt.xlabel('laser freq. detuning (Hz)')
c=plt.ylabel('T`otal Scattering Rate')
c=plt.title('Detuning vs Total Scattering Rate')

plt.figure(figsize=(12, 10))
d=plt.plot(df,To)
d=plt.xlabel('laser freq. detuning (Hz)')
d=plt.ylabel('Net Torque by Laser')
d=plt.title('Detuning vs Net Torque by Laser')

print(U)
# Out:
# Beginning...
# -------------
# Feeding in detuning -150000126.7 1 of 37 Evaluations
# u/T recorded: 2.816435266869507 0.004308185713604313 after 9 integral calls.
# -------------
# Feeding in detuning -145861234.315 2 of 37 Evaluations
# u/T recorded: 2.782755519301216 0.004205764725307287 after 9 integral calls.
# -------------
# Feeding in detuning -141722341.93 3 of 37 Evaluations
# u/T recorded: 2.7486137881606907 0.004103196447813833 after 8 integral calls.
# -------------
# Feeding in detuning -137583449.545 4 of 37 Evaluations
# u/T recorded: 2.7139668292173558 0.004000404794969446 after 9 integral calls.
# -------------
# Feeding in detuning -133444557.16 5 of 37 Evaluations
# u/T recorded: 2.678814693127318 0.0038974469566657164 after 9 integral calls.
# -------------
# Feeding in detuning -129305664.775 6 of 37 Evaluations
# u/T recorded: 2.6431274122231803 0.00379429476171424 after 9 integral calls.
# -------------
# Feeding in detuning -125166772.391 7 of 37 Evaluations
# u/T recorded: 2.606877521683678 0.0036909326723404703 after 9 integral calls.
# -------------
# Feeding in detuning -121027880.006 8 of 37 Evaluations
# u/T recorded: 2.5699290046689893 0.0035870474401268433 after 9 integral calls.
# -------------
# Feeding in detuning -116888987.621 9 of 37 Evaluations
# u/T recorded: 2.5324180316038767 0.0034830977515328205 after 10 integral calls.
# -------------
# Feeding in detuning -112750095.236 10 of 37 Evaluations
# u/T recorded: 2.494201984035661 0.0033787659531022717 after 10 integral calls.
# -------------
# Feeding in detuning -108611202.851 11 of 37 Evaluations
# u/T recorded: 2.455254708431635 0.0032740700997955664 after 10 integral calls.
# -------------
# Feeding in detuning -104472310.466 12 of 37 Evaluations
# u/T recorded: 2.4155137985582145 0.0031689392526383932 after 10 integral calls.
# -------------
# Feeding in detuning -100333418.081 13 of 37 Evaluations
# u/T recorded: 2.374924960398881 0.0030633361249527017 after 10 integral calls.
# -------------
# Feeding in detuning -96194525.6965 14 of 37 Evaluations
# u/T recorded: 2.333453393459591 0.002957284661040069 after 9 integral calls.
# -------------
# Feeding in detuning -92055633.3116 15 of 37 Evaluations
# u/T recorded: 2.290894876984275 0.0028503959392559798 after 9 integral calls.
# -------------
# Feeding in detuning -87916740.9268 16 of 37 Evaluations
# u/T recorded: 2.247248863864672 0.0027428193687590936 after 10 integral calls.
# -------------
# Feeding in detuning -83777848.5419 17 of 37 Evaluations
# u/T recorded: 2.202363885798705 0.0026343472553527433 after 9 integral calls.
# -------------
# Feeding in detuning -79638956.157 18 of 37 Evaluations
# u/T recorded: 2.156073133964218 0.0025247701363606155 after 9 integral calls.
# -------------
# Feeding in detuning -75500063.7722 19 of 37 Evaluations
# u/T recorded: 2.108217578908106 0.00241393587511471 after 10 integral calls.
# -------------
# Feeding in detuning -71361171.3873 20 of 37 Evaluations
# u/T recorded: 2.058476700616105 0.0023013717618669146 after 10 integral calls.
# -------------
# Feeding in detuning -67222279.0025 21 of 37 Evaluations
# u/T recorded: 2.006594606410851 0.0021868256018755497 after 10 integral calls.
# -------------
# Feeding in detuning -63083386.6176 22 of 37 Evaluations
# u/T recorded: 1.9521734784567615 0.002069815739690322 after 10 integral calls.
# -------------
# Feeding in detuning -58944494.2327 23 of 37 Evaluations
# u/T recorded: 1.8947386247439857 0.0019498153514364669 after 10 integral calls.
# -------------
# Feeding in detuning -54805601.8479 24 of 37 Evaluations
# u/T recorded: 1.833859150607684 0.0018265300512072867 after 10 integral calls.
# -------------
# Feeding in detuning -50666709.463 25 of 37 Evaluations
# u/T recorded: 1.7694867097369258 0.00170055028599754 after 10 integral calls.
# -------------
# Feeding in detuning -46527817.0781 26 of 37 Evaluations
# u/T recorded: 1.701783378058834 0.0015729083697911214 after 9 integral calls.
# -------------
# Feeding in detuning -42388924.6933 27 of 37 Evaluations
# u/T recorded: 1.631513925094176 0.0014456941987963888 after 9 integral calls.
# -------------
# Feeding in detuning -38250032.3084 28 of 37 Evaluations
# u/T recorded: 1.5604264501293506 0.0013224567420776513 after 9 integral calls.
# -------------
# Feeding in detuning -34111139.9236 29 of 37 Evaluations
# u/T recorded: 1.491816830312159 0.0012087204599595528 after 9 integral calls.
# -------------
# Feeding in detuning -29972247.5387 30 of 37 Evaluations
# u/T recorded: 1.429934493341111 0.0011105219666362482 after 8 integral calls.
# -------------
# Feeding in detuning -25833355.1538 31 of 37 Evaluations
# u/T recorded: 1.3798446946020326 0.0010340827290659038 after 10 integral calls.
# -------------
# Feeding in detuning -21694462.769 32 of 37 Evaluations
# u/T recorded: 1.3455583972009437 0.0009833315424767693 after 9 integral calls.
# -------------
# Feeding in detuning -17555570.3841 33 of 37 Evaluations
# u/T recorded: 1.3344198651689942 0.0009671188890836631 after 9 integral calls.
# -------------
# Feeding in detuning -13416677.9992 34 of 37 Evaluations
# u/T recorded: 1.3475457567149027 0.0009862384047574643 after 10 integral calls.
# -------------
# Feeding in detuning -9277785.61439 35 of 37 Evaluations
# u/T recorded: 1.3843176098549348 0.0010407977764017118 after 10 integral calls.
# -------------
# Feeding in detuning -5138893.22953 36 of 37 Evaluations
# u/T recorded: 1.4397559642783988 0.0011258295438239315 after 10 integral calls.
# -------------
# Feeding in detuning -1000000.84466 37 of 37 Evaluations
# u/T recorded: 1.5043853554889353 0.0012291731437749742 after 10 integral calls.
# [0.004308185713604313, 0.004205764725307288, 0.004103196447813834, 0.004000404794969447, 0.0038974469566657164, 0.00379429476171424, 0.0036909326723404707, 0.0035870474401268437, 0.003483097751532821, 0.0033787659531022726, 0.003274070099795567, 0.0031689392526383937, 0.0030633361249527017, 0.0029572846610400696, 0.00285039593925598, 0.002742819368759094, 0.0026343472553527437, 0.0025247701363606155, 0.00241393587511471, 0.002301371761866915, 0.0021868256018755497, 0.002069815739690322, 0.0019498153514364669, 0.001826530051207287, 0.00170055028599754, 0.0015729083697911216, 0.001445694198796389, 0.0013224567420776513, 0.0012087204599595528, 0.0011105219666362484, 0.0010340827290659038, 0.0009833315424767695, 0.0009671188890836633, 0.0009862384047574643, 0.001040797776401712, 0.0011258295438239317, 0.0012291731437749742]
# 0.0009671188890836633
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-c297030b10db> in <module>()
#     179 d=plt.title('Detuning vs Net Torque by Laser')
#     180
# --> 181 print("Elapsed time:",time.time() - start_time)
#     182 print(U)
#
# NameError: name 'start_time' is not defined

# %% [markdown]
# # The code below is configured to conduct a 2-dimensional parameter scan

# %%
# %matplotlib inline
#Adopted from MATLAB code by Charles Xu.
#Steven B. Torrisi Summer 2015

import time
import numpy as np
import scipy as sp
import scipy.optimize as opt
import scipy.integrate as integ
import matplotlib.pyplot as plt
from scipy.constants import pi
plt.rcParams['font.size'] = 16

#Standard parameters and other constants
hbar=1.054E-34;
c=2.9979E8;
lambd=313.112E-9;   #transition wavelength

k=2*pi/lambd;       #Be+ laser wavenumber; assuming offset dw is sufficiently 
                    #small that the shift in the wave number due to dw/(2*pi) can be neglected

kB=1.38E-23;        #Boltzmann's constant
m=8.96*1.673E-27;   # Be+ ion mass

#Input parameters
lowest_df = -150.0E6;     #lowest (most red) detuning of laser beam from atomic 
                          #transition frequency; in Hz; negative numbers correspond to red detuning.
highest_df = -1.0E6;      #highest tuning of the laser beam frequency
incr = 4.0E6;             #increment to be used in going from lowest frequency tuning to highest.
                          #If increment greater than highest-lowest, then only the lowest
                          #frequency detuning will be evaluated
N = int(round((highest_df-lowest_df)/incr));
df = np.linspace(lowest_df,highest_df,N) #Go from lowest df to highest in N steps
                                         #(interpolates linearly)
dw = 2*pi*df;
d = 40.00E-6;               #offset of laser beam from the center of the array in meters, 
                    #positive offsets corresponds to miving the laser beam to the side of 
                    #the cloud (or array) that is receding from the laser beam direction
WR = 2*pi*45.0E3;           #angular rotation frequency in s^{-1}
RP = 225.0E-6;              #radius of ion array in meters


R_bar=(hbar*k)**2/(2*m);    #recoil energy
T = 20.0E-3               #initial guess in temperature in Kelvin

global GAMMA, VK, RNORM, U0, RP, WR, WY, d, S0, SIG
#Define Globals
RNORM=R_bar/(hbar*k);      #A reduced recoil energy
GAMMA=2*pi*18.0E6;         #natural linewidth
VK=GAMMA/(2*k);            # Reduced line width
U0=np.sqrt(2*kB*T/m);      #initial thermal velocity used in Boltzmann factor 
WY=30.0E-6                 #beam width in meters
SIG=2.77E9                 # density at origin
S0=.5                    # Saturation parameter

def density(x,y):
    """
    Defines a density scaling which returns 0 outside of the circular bounds of the crystal.
    Useful because it allows for rectangular integration bounds (i.e. [-r,r])
    instead of complicated functional bounds which are difficult to work with.
    """
    global RP
    rad=x**2+y**2
    if rad<=(RP**2):
        return np.sqrt(1-(rad)/RP**2)
    else:
        return 0

def dEnosaturation(u,detun,offset=d):
    global GAMMA, VK, RNORM,  U0, RP, WR, WY, counter
        
    delta = 2.*detun/GAMMA;
    ret = integ.tplquad(lambda y,x,v:\
                        density(x,y)\
                        *np.exp(-(y-offset)**2 /WY**2) *\
                        ((v)+2*RNORM/u)*np.exp(-v**2)/\
                        (1+(delta-(WR*y/VK)-(u*v/VK))**2),\
                        -np.inf, np.inf,\
                        lambda x: -1*RP, lambda x: RP,\
                        lambda x,y: -1*RP, lambda x,y: RP)
    
    #print("Integral Evaluated",ret[0],"with temperature",u**2*8.96*1.673E-27/(2*1.38E-23))
    counter+=1
    return ret[0]

def dEcomplete(u,detun,offset=d):
    global GAMMA, VK, RNORM,  U0, RP, WR, WY, S0, counter
        
    delta = 2.*detun/GAMMA;
    ret = integ.tplquad(lambda y,x,v:\
                        density(x,y)\
                        *np.exp(-(y-offset)**2 /WY**2) *\
                        ((v)+2*RNORM/u)*np.exp(-v**2)/\
                        ((1+2*S0*np.exp(-2*(y-d)**2 /WY**2)\
                          +(delta-(WR*y/VK)-(u*v/VK))**2)),\
                        -np.inf, np.inf,\
                        lambda x: -1*RP, lambda x: RP,\
                        lambda x,y: -1*RP, lambda x,y: RP)
    
    #print("Integral Evaluated",ret[0],"with temperature",u**2*8.96*1.673E-27/(2*1.38E-23))
    counter+=1
    return ret[0]

def totalscatter(ueq,detun):

    global GAMMA, VK, RNORM, U0, RP, WR, WY, d,S0,SIG
    delta = 2.*detun/GAMMA;
    constants= GAMMA*S0*SIG*ueq/np.sqrt(np.pi)
    ret = integ.tplquad(lambda y,x,v:\
                        \
                        density(x,y)\
                        *np.exp(-2*(y-d)**2 /WY**2) *\
                        np.exp(-v**2)/\
                        (1+2*S0*np.exp(-2*(y-d)**2 /WY**2)+\
                        (delta-(WR*y/VK)-(ueq*v/VK))**2),\
                        \
                        -np.inf, np.inf,\
                        lambda x: -1*RP, lambda x: RP,\
                        lambda x,y: -1*RP, lambda x,y: RP)
    
    return ret[0]*constants

def totaltorque(ueq,detun):
    global GAMMA, VK, RNORM, U0, RP, WR, WY, d,S0,SIG
    delta = 2.*detun/GAMMA;
    constants= (hbar*k)*GAMMA*S0*SIG*ueq/np.sqrt(np.pi)
    ret = integ.tplquad(lambda v,x,y:\
                        \
                        density(x,y)\
                        *np.exp(-2*(y-d)**2 /WY**2)*y*\
                        np.exp(-v**2)/\
                        (1+2*S0*np.exp(-2*(y-d)**2 /WY**2)+\
                        (delta-(WR*y/VK)-(ueq*v/VK))**2),\
                        \
                        -1*RP, RP,\
                        lambda x: -1*RP, lambda x: RP,\
                        lambda x,y: -1*np.inf, lambda x,y: np.inf,\
                        epsabs=1.49e-10, epsrel=1.49e-10)    
    
    return ret[0]*constants

def getroot(detoffset):
    global GAMMA, VK, RNORM, U0, RP, WR, WY, d,S0,SIG
    print("Trying detuning",detoffset[0]," and offset ",detoffset[1])
    return (opt.brentq(dEver3,umin,umax,args=(detoffset[0],detoffset[1]),xtol=1e-6, rtol=3.0e-8))**2*m/(2*kB)

def getrootdetun(detun):
    global GAMMA, VK, RNORM, U0, RP, WR, WY, d,S0,SIG
    print("Trying detuning",detun)
    return (opt.brentq(dEver3,umin,umax,args=(detun,3.98794261e-05),xtol=1e-6, rtol=3.0e-8))**2*m/(2*kB)
#########################################
#Sc=[0] * (N)
#To=[0]*(N)
#print(dE1(1,dw[0],y))
#print(totalscatter(np.sqrt(.05*kB*2/m),-20.0E6))

Tmax=1.0E-1
Tmin=1.0E-5
umax=np.sqrt(Tmax*kB*2/m)
umin=np.sqrt(Tmin*kB*2/m)
global counter
counter=0
print("Beginning...")

#opt.fmin(getroot,[-50.0E6,15.0E-6],args=(detun))
#print(opt.minimize(getroot,[-50.0E6,50.0E-6],method='TNC',bounds=[[-160.0E6,-1.0E6],[0,220.0E-6]]))

#print(opt.minimize(getrootdetun,[-10.0E6] ,method='TNC',bounds=[[-150.0E6,-5.0E6]]))
#return

df = np.linspace(-80.0E6,-5.0E6,30)
doff= np.linspace(0.00,40.0E-6,30)
dw = 2*pi*df;
U=np.zeros([len(df),len(doff)])

for W in range(len(dw)):
    for D in range(len(doff)):
        
        print("-------------")
        print("Feeding in detuning/offset",dw[W]/(2*3.14159),doff[D], W*(len(doff))+D+1, "of", len(df)*len(doff), "Evaluations")
        try:
            U[D][W]=opt.brentq(dEcomplete,umin,umax,args=(dw[W],doff[D]),xtol=1e-4, rtol=3.0e-7)
        except:
            try: 
                U[D][W]=opt.brentq(dEcomplete,umin*.1,umax*10,args=(dw[W],doff[D]),xtol=1e-4, rtol=3.0e-7)
            except:
                U[D][W]=opt.brentq(dEcomplete,umin*.01,umax*100,args=(dw[W],doff[D]),xtol=1e-4, rtol=3.0e-7)
        print("u/T recorded:",U[D][W],((U[D][W])*U[D][W]*8.96*1.673E-27/(2*1.38E-23)),"after",counter,"integral calls.")

        counter=0
Teq=np.array([x**2*m/(2*kB) for x in U]);
print(U)
print(Teq)

#plt.figure(figsize=(12, 10))
#b=plt.plot(df,Teq)
#b=plt.xlabel('laser freq. detuning (Hz)')
#b=plt.ylabel('equilibrium temp (K)')
#b=plt.title('Plot of the Equilibrium Temperature')
plt.figure(figsize=(12, 10))
#cmap = plt.get_cmap('PiYG')
#levels = MaxNLocator(nbins=15).tick_values(Teq.min(), Teq.max())
#norm = BoundaryNorm(levels, ncolors=cmap.N, clip=True)
#im = plt.pcolormesh(df, doff, Teq, cmap=cmap, norm=norm)
CS = plt.contour(doff, df, Teq)
plt.clabel(CS, inline=1, fontsize=10)
plt.title('Simplest default with labels')
"""
a=plt.plot(df,Teq)
a=plt.xlabel('laser freq. detuning (Hz)')
a=plt.ylabel('equilibrium temp (K)')
a=plt.title('Plot of the Equilibrium Temperature')
a=plt.yscale('log', nonposy='clip')

returnplt.figure(figsize=(12, 10))
c=plt.plot(df,Sc)
c=plt.xlabel('laser freq. detuning (Hz)')
c=plt.ylabel('T`otal Scattering Rate')
c=plt.title('Detuning vs Total Scattering Rate')

plt.figure(figsize=(12, 10))
d=plt.plot(df,To)
d=plt.xlabel('laser freq. detuning (Hz)')
d=plt.ylabel('Net Torque by Laser')
d=plt.title('Detuning vs Net Torque by Laser')

print(U)
"""
# Out:
# Beginning...
# -------------
# Feeding in detuning/offset -80000067.5732 0.0 1 of 900 Evaluations
# u/T recorded: 1.65200813101 0.00148224239115 after 9 integral calls.
# -------------
# Feeding in detuning/offset -80000067.5732 1.37931034483e-06 2 of 900 Evaluations
# u/T recorded: 1.67321937764 0.00152054976912 after 9 integral calls.
# -------------
# Feeding in detuning/offset -80000067.5732 2.75862068966e-06 3 of 900 Evaluations
# u/T recorded: 1.69412526077 0.0015587838764 after 9 integral calls.
# -------------
# Feeding in detuning/offset -80000067.5732 4.13793103448e-06 4 of 900 Evaluations
# u/T recorded: 1.7148031045 0.00159706793677 after 9 integral calls.
# -------------
# Feeding in detuning/offset -80000067.5732 5.51724137931e-06 5 of 900 Evaluations
# u/T recorded: 1.73520404476 0.00163529448182 after 9 integral calls.
# -------------
# Feeding in detuning/offset -80000067.5732 6.89655172414e-06 6 of 900 Evaluations
# u/T recorded: 1.75531429265 0.0016734188115 after 9 integral calls.
# -------------
# Feeding in detuning/offset -80000067.5732 8.27586206897e-06 7 of 900 Evaluations
# u/T recorded: 1.77523637687 0.00171161957904 after 9 integral calls.
# -------------
# Feeding in detuning/offset -80000067.5732 9.65517241379e-06 8 of 900 Evaluations
# u/T recorded: 1.794840607 0.00174963171219 after 9 integral calls.
# -------------
# Feeding in detuning/offset -80000067.5732 1.10344827586e-05 9 of 900 Evaluations
# u/T recorded: 1.81406151758 0.00178730590279 after 9 integral calls.
# -------------
# Feeding in detuning/offset -80000067.5732 1.24137931034e-05 10 of 900 Evaluations
# u/T recorded: 1.83294781706 0.00182471511956 after 9 integral calls.
# -------------
# Feeding in detuning/offset -80000067.5732 1.37931034483e-05 11 of 900 Evaluations
# u/T recorded: 1.85150891209 0.00186185768723 after 9 integral calls.
# -------------
# Feeding in detuning/offset -80000067.5732 1.51724137931e-05 12 of 900 Evaluations
# u/T recorded: 1.86974898893 0.00189872243797 after 9 integral calls.
# -------------
# Feeding in detuning/offset -80000067.5732 1.65517241379e-05 13 of 900 Evaluations
# u/T recorded: 1.88768956855 0.00193533441881 after 9 integral calls.
# -------------
# Feeding in detuning/offset -80000067.5732 1.79310344828e-05 14 of 900 Evaluations
# u/T recorded: 1.90532751733 0.00197166963466 after 9 integral calls.
# -------------
# Feeding in detuning/offset -80000067.5732 1.93103448276e-05 15 of 900 Evaluations
# u/T recorded: 1.92267790332 0.00200774216053 after 9 integral calls.
# -------------
# Feeding in detuning/offset -80000067.5732 2.06896551724e-05 16 of 900 Evaluations
# u/T recorded: 1.93975163064 0.00204355871288 after 9 integral calls.
# -------------
# Feeding in detuning/offset -80000067.5732 2.20689655172e-05 17 of 900 Evaluations
# u/T recorded: 1.95656351692 0.00207913539057 after 9 integral calls.
# -------------
# Feeding in detuning/offset -80000067.5732 2.34482758621e-05 18 of 900 Evaluations
# u/T recorded: 1.97311801439 0.00211446739091 after 9 integral calls.
# -------------
# Feeding in detuning/offset -80000067.5732 2.48275862069e-05 19 of 900 Evaluations
# u/T recorded: 1.98909604351 0.00214885136031 after 9 integral calls.
# -------------
# Feeding in detuning/offset -80000067.5732 2.62068965517e-05 20 of 900 Evaluations
# u/T recorded: 2.00594242193 0.00218540430636 after 9 integral calls.
# -------------
# Feeding in detuning/offset -80000067.5732 2.75862068966e-05 21 of 900 Evaluations
# u/T recorded: 2.02151215009 0.00221946131891 after 9 integral calls.
# -------------
# Feeding in detuning/offset -80000067.5732 2.89655172414e-05 22 of 900 Evaluations
# u/T recorded: 2.03680916473 0.00225317824546 after 9 integral calls.
# -------------
# Feeding in detuning/offset -80000067.5732 3.03448275862e-05 23 of 900 Evaluations
# u/T recorded: 2.05241981821 0.00228784852812 after 10 integral calls.
# -------------
# Feeding in detuning/offset -80000067.5732 3.1724137931e-05 24 of 900 Evaluations
# u/T recorded: 2.06766788196 0.00232196907851 after 10 integral calls.
# -------------
# Feeding in detuning/offset -80000067.5732 3.31034482759e-05 25 of 900 Evaluations
# u/T recorded: 2.08274374819 0.00235595259493 after 10 integral calls.
# -------------
# Feeding in detuning/offset -80000067.5732 3.44827586207e-05 26 of 900 Evaluations
# u/T recorded: 2.09761367749 0.00238971374155 after 10 integral calls.
# -------------
# Feeding in detuning/offset -80000067.5732 3.58620689655e-05 27 of 900 Evaluations
# u/T recorded: 2.11231559181 0.00242332954962 after 10 integral calls.
# -------------
# Feeding in detuning/offset -80000067.5732 3.72413793103e-05 28 of 900 Evaluations
# u/T recorded: 2.12683230743 0.00245675227086 after 10 integral calls.
# -------------
# Feeding in detuning/offset -80000067.5732 3.86206896552e-05 29 of 900 Evaluations
# u/T recorded: 2.14122440082 0.0024901140358 after 10 integral calls.
# -------------
# Feeding in detuning/offset -80000067.5732 4e-05 30 of 900 Evaluations
# u/T recorded: 2.15544123199 0.00252329043383 after 10 integral calls.
# -------------
# Feeding in detuning/offset -77413858.4921 0.0 31 of 900 Evaluations
# u/T recorded: 1.60650365044 0.00140171042072 after 9 integral calls.
# -------------
# Feeding in detuning/offset -77413858.4921 1.37931034483e-06 32 of 900 Evaluations
# u/T recorded: 1.62808778707 0.00143962873157 after 9 integral calls.
# -------------
# Feeding in detuning/offset -77413858.4921 2.75862068966e-06 33 of 900 Evaluations
# u/T recorded: 1.64951679635 0.00147777512817 after 9 integral calls.
# -------------
# Feeding in detuning/offset -77413858.4921 4.13793103448e-06 34 of 900 Evaluations
# u/T recorded: 1.67070358719 0.00151598072243 after 9 integral calls.
# -------------
# Feeding in detuning/offset -77413858.4921 5.51724137931e-06 35 of 900 Evaluations
# u/T recorded: 1.6917215849 0.00155436371546 after 9 integral calls.
# -------------
# Feeding in detuning/offset -77413858.4921 6.89655172414e-06 36 of 900 Evaluations
# u/T recorded: 1.71256365822 0.0015928992804 after 9 integral calls.
# -------------
# Feeding in detuning/offset -77413858.4921 8.27586206897e-06 37 of 900 Evaluations
# u/T recorded: 1.7331157047 0.00163136065517 after 9 integral calls.
# -------------
# Feeding in detuning/offset -77413858.4921 9.65517241379e-06 38 of 900 Evaluations
# u/T recorded: 1.75335231764 0.00166968002692 after 9 integral calls.
# -------------
# Feeding in detuning/offset -77413858.4921 1.10344827586e-05 39 of 900 Evaluations
# u/T recorded: 1.77327108979 0.00170783195739 after 9 integral calls.
# -------------
# Feeding in detuning/offset -77413858.4921 1.24137931034e-05 40 of 900 Evaluations
# u/T recorded: 1.7928948346 0.00174584024486 after 9 integral calls.
# -------------
# Feeding in detuning/offset -77413858.4921 1.37931034483e-05 41 of 900 Evaluations
# u/T recorded: 1.81219019992 0.00178362036956 after 9 integral calls.
# -------------
# Feeding in detuning/offset -77413858.4921 1.51724137931e-05 42 of 900 Evaluations
# u/T recorded: 1.83114714904 0.00182113171996 after 9 integral calls.
# -------------
# Feeding in detuning/offset -77413858.4921 1.65517241379e-05 43 of 900 Evaluations
# u/T recorded: 1.84972172196 0.00185826506318 after 9 integral calls.
# -------------
# Feeding in detuning/offset -77413858.4921 1.79310344828e-05 44 of 900 Evaluations
# u/T recorded: 1.86798957687 0.00189515076774 after 9 integral calls.
# -------------
# Feeding in detuning/offset -77413858.4921 1.93103448276e-05 45 of 900 Evaluations
# u/T recorded: 1.88595631789 0.0019317820554 after 9 integral calls.
# -------------
# Feeding in detuning/offset -77413858.4921 2.06896551724e-05 46 of 900 Evaluations
# u/T recorded: 1.90362361984 0.00196814475956 after 9 integral calls.
# -------------
# Feeding in detuning/offset -77413858.4921 2.20689655172e-05 47 of 900 Evaluations
# u/T recorded: 1.92100904881 0.00200425829523 after 9 integral calls.
# -------------
# Feeding in detuning/offset -77413858.4921 2.34482758621e-05 48 of 900 Evaluations
# u/T recorded: 1.93812333857 0.00204012929049 after 9 integral calls.
# -------------
# Feeding in detuning/offset -77413858.4921 2.48275862069e-05 49 of 900 Evaluations
# u/T recorded: 1.9548230146 0.00207543795844 after 9 integral calls.
# -------------
# Feeding in detuning/offset -77413858.4921 2.62068965517e-05 50 of 900 Evaluations
# u/T recorded: 1.97198431076 0.00211203825017 after 9 integral calls.
# -------------
# Feeding in detuning/offset -77413858.4921 2.75862068966e-05 51 of 900 Evaluations
# u/T recorded: 1.98801985748 0.00214652674834 after 9 integral calls.
# -------------
# Feeding in detuning/offset -77413858.4921 2.89655172414e-05 52 of 900 Evaluations
# u/T recorded: 2.0037728416 0.00218067949868 after 9 integral calls.
# -------------
# Feeding in detuning/offset -77413858.4921 3.03448275862e-05 53 of 900 Evaluations
# u/T recorded: 2.01989110677 0.00221590319001 after 9 integral calls.
# -------------
# Feeding in detuning/offset -77413858.4921 3.1724137931e-05 54 of 900 Evaluations
# u/T recorded: 2.03555215349 0.00225039801797 after 10 integral calls.
# -------------
# Feeding in detuning/offset -77413858.4921 3.31034482759e-05 55 of 900 Evaluations
# u/T recorded: 2.05103226788 0.00228475614722 after 10 integral calls.
# -------------
# Feeding in detuning/offset -77413858.4921 3.44827586207e-05 56 of 900 Evaluations
# u/T recorded: 2.06630522007 0.00231890957732 after 10 integral calls.
# -------------
# Feeding in detuning/offset -77413858.4921 3.58620689655e-05 57 of 900 Evaluations
# u/T recorded: 2.08137647797 0.00235286035998 after 10 integral calls.
# -------------
# Feeding in detuning/offset -77413858.4921 3.72413793103e-05 58 of 900 Evaluations
# u/T recorded: 2.09626951166 0.00238665203158 after 10 integral calls.
# -------------
# Feeding in detuning/offset -77413858.4921 3.86206896552e-05 59 of 900 Evaluations
# u/T recorded: 2.11096719913 0.00242023668139 after 10 integral calls.
# -------------
# Feeding in detuning/offset -77413858.4921 4e-05 60 of 900 Evaluations
# u/T recorded: 2.12553296649 0.00245375139138 after 10 integral calls.
# -------------
# Feeding in detuning/offset -74827649.4111 0.0 61 of 900 Evaluations
# u/T recorded: 1.56056119174 0.00132268513816 after 9 integral calls.
# -------------
# Feeding in detuning/offset -74827649.4111 1.37931034483e-06 62 of 900 Evaluations
# u/T recorded: 1.5823308654 0.00135984518501 after 9 integral calls.
# -------------
# Feeding in detuning/offset -74827649.4111 2.75862068966e-06 63 of 900 Evaluations
# u/T recorded: 1.60408296673 0.00139748940172 after 9 integral calls.
# -------------
# Feeding in detuning/offset -74827649.4111 4.13793103448e-06 64 of 900 Evaluations
# u/T recorded: 1.62575052823 0.00143549827891 after 9 integral calls.
# -------------
# Feeding in detuning/offset -74827649.4111 5.51724137931e-06 65 of 900 Evaluations
# u/T recorded: 1.64726251089 0.00147373873322 after 9 integral calls.
# -------------
# Feeding in detuning/offset -74827649.4111 6.89655172414e-06 66 of 900 Evaluations
# u/T recorded: 1.668641841 0.00151224141291 after 9 integral calls.
# -------------
# Feeding in detuning/offset -74827649.4111 8.27586206897e-06 67 of 900 Evaluations
# u/T recorded: 1.68974046116 0.0015507253109 after 9 integral calls.
# -------------
# Feeding in detuning/offset -74827649.4111 9.65517241379e-06 68 of 900 Evaluations
# u/T recorded: 1.71055157637 0.00158915850156 after 9 integral calls.
# -------------
# Feeding in detuning/offset -74827649.4111 1.10344827586e-05 69 of 900 Evaluations
# u/T recorded: 1.73109050901 0.00162755029878 after 9 integral calls.
# -------------
# Feeding in detuning/offset -74827649.4111 1.24137931034e-05 70 of 900 Evaluations
# u/T recorded: 1.75134591715 0.0016658609085 after 9 integral calls.
# -------------
# Feeding in detuning/offset -74827649.4111 1.37931034483e-05 71 of 900 Evaluations
# u/T recorded: 1.77127990447 0.00170399870178 after 9 integral calls.
# -------------
# Feeding in detuning/offset -74827649.4111 1.51724137931e-05 72 of 900 Evaluations
# u/T recorded: 1.79091289047 0.00174198252241 after 9 integral calls.
# -------------
# Feeding in detuning/offset -74827649.4111 1.65517241379e-05 73 of 900 Evaluations
# u/T recorded: 1.81020262596 0.00177971003683 after 9 integral calls.
# -------------
# Feeding in detuning/offset -74827649.4111 1.79310344828e-05 74 of 900 Evaluations
# u/T recorded: 1.82920525775 0.00181727122772 after 9 integral calls.
# -------------
# Feeding in detuning/offset -74827649.4111 1.93103448276e-05 75 of 900 Evaluations
# u/T recorded: 1.84785486614 0.00185451599943 after 9 integral calls.
# -------------
# Feeding in detuning/offset -74827649.4111 2.06896551724e-05 76 of 900 Evaluations
# u/T recorded: 1.86616577776 0.00189145193877 after 9 integral calls.
# -------------
# Feeding in detuning/offset -74827649.4111 2.20689655172e-05 77 of 900 Evaluations
# u/T recorded: 1.88417485286 0.00192813427547 after 9 integral calls.
# -------------
# Feeding in detuning/offset -74827649.4111 2.34482758621e-05 78 of 900 Evaluations
# u/T recorded: 1.90189303583 0.00196456790583 after 9 integral calls.
# -------------
# Feeding in detuning/offset -74827649.4111 2.48275862069e-05 79 of 900 Evaluations
# u/T recorded: 1.91929734887 0.00200068812948 after 9 integral calls.
# -------------
# Feeding in detuning/offset -74827649.4111 2.62068965517e-05 80 of 900 Evaluations
# u/T recorded: 1.93657820798 0.00203687768152 after 9 integral calls.
# -------------
# Feeding in detuning/offset -74827649.4111 2.75862068966e-05 81 of 900 Evaluations
# u/T recorded: 1.95348846317 0.00207260513601 after 9 integral calls.
# -------------
# Feeding in detuning/offset -74827649.4111 2.89655172414e-05 82 of 900 Evaluations
# u/T recorded: 1.96991269922 0.00210760309863 after 9 integral calls.
# -------------
# Feeding in detuning/offset -74827649.4111 3.03448275862e-05 83 of 900 Evaluations
# u/T recorded: 1.98637663886 0.00214297974656 after 9 integral calls.
# -------------
# Feeding in detuning/offset -74827649.4111 3.1724137931e-05 84 of 900 Evaluations
# u/T recorded: 2.00253298386 0.00217798169201 after 9 integral calls.
# -------------
# Feeding in detuning/offset -74827649.4111 3.31034482759e-05 85 of 900 Evaluations
# u/T recorded: 2.01846905809 0.00221278419713 after 9 integral calls.
# -------------
# Feeding in detuning/offset -74827649.4111 3.44827586207e-05 86 of 900 Evaluations
# u/T recorded: 2.03414556732 0.00224728899904 after 10 integral calls.
# -------------
# Feeding in detuning/offset -74827649.4111 3.58620689655e-05 87 of 900 Evaluations
# u/T recorded: 2.0496420384 0.0022816598928 after 10 integral calls.
# -------------
# Feeding in detuning/offset -74827649.4111 3.72413793103e-05 88 of 900 Evaluations
# u/T recorded: 2.06492451179 0.00231581161492 after 10 integral calls.
# -------------
# Feeding in detuning/offset -74827649.4111 3.86206896552e-05 89 of 900 Evaluations
# u/T recorded: 2.08001872631 0.00234979166183 after 10 integral calls.
# -------------
# Feeding in detuning/offset -74827649.4111 4e-05 90 of 900 Evaluations
# u/T recorded: 2.09491984243 0.00238357976075 after 10 integral calls.
# -------------
# Feeding in detuning/offset -72241440.3301 0.0 91 of 900 Evaluations
# u/T recorded: 1.51499082806 0.00124656484711 after 9 integral calls.
# -------------
# Feeding in detuning/offset -72241440.3301 1.37931034483e-06 92 of 900 Evaluations
# u/T recorded: 1.53656577553 0.00128232225641 after 9 integral calls.
# -------------
# Feeding in detuning/offset -72241440.3301 2.75862068966e-06 93 of 900 Evaluations
# u/T recorded: 1.55830771428 0.00131886793559 after 9 integral calls.
# -------------
# Feeding in detuning/offset -72241440.3301 4.13793103448e-06 94 of 900 Evaluations
# u/T recorded: 1.58008418303 0.00135598635706 after 9 integral calls.
# -------------
# Feeding in detuning/offset -72241440.3301 5.51724137931e-06 95 of 900 Evaluations
# u/T recorded: 1.60185038255 0.00139360201988 after 9 integral calls.
# -------------
# Feeding in detuning/offset -72241440.3301 6.89655172414e-06 96 of 900 Evaluations
# u/T recorded: 1.62357873865 0.0014316655656 after 9 integral calls.
# -------------
# Feeding in detuning/offset -72241440.3301 8.27586206897e-06 97 of 900 Evaluations
# u/T recorded: 1.64509426014 0.00146986159517 after 9 integral calls.
# -------------
# Feeding in detuning/offset -72241440.3301 9.65517241379e-06 98 of 900 Evaluations
# u/T recorded: 1.66640580039 0.00150819121172 after 9 integral calls.
# -------------
# Feeding in detuning/offset -72241440.3301 1.10344827586e-05 99 of 900 Evaluations
# u/T recorded: 1.68749814429 0.0015466123593 after 9 integral calls.
# -------------
# Feeding in detuning/offset -72241440.3301 1.24137931034e-05 100 of 900 Evaluations
# u/T recorded: 1.70835488787 0.00158507953108 after 9 integral calls.
# -------------
# Feeding in detuning/offset -72241440.3301 1.37931034483e-05 101 of 900 Evaluations
# u/T recorded: 1.72893180838 0.00162349366141 after 9 integral calls.
# -------------
# Feeding in detuning/offset -72241440.3301 1.51724137931e-05 102 of 900 Evaluations
# u/T recorded: 1.74922718383 0.00166183271507 after 9 integral calls.
# -------------
# Feeding in detuning/offset -72241440.3301 1.65517241379e-05 103 of 900 Evaluations
# u/T recorded: 1.76917981146 0.00169996045314 after 9 integral calls.
# -------------
# Feeding in detuning/offset -72241440.3301 1.79310344828e-05 104 of 900 Evaluations
# u/T recorded: 1.78883033123 0.00173793355662 after 9 integral calls.
# -------------
# Feeding in detuning/offset -72241440.3301 1.93103448276e-05 105 of 900 Evaluations
# u/T recorded: 1.80818729126 0.00177574946937 after 9 integral calls.
# -------------
# Feeding in detuning/offset -72241440.3301 2.06896551724e-05 106 of 900 Evaluations
# u/T recorded: 1.82720109035 0.00181329122549 after 9 integral calls.
# -------------
# Feeding in detuning/offset -72241440.3301 2.20689655172e-05 107 of 900 Evaluations
# u/T recorded: 1.84589292881 0.00185058007059 after 9 integral calls.
# -------------
# Feeding in detuning/offset -72241440.3301 2.34482758621e-05 108 of 900 Evaluations
# u/T recorded: 1.86428311145 0.00188763751172 after 9 integral calls.
# -------------
# Feeding in detuning/offset -72241440.3301 2.48275862069e-05 109 of 900 Evaluations
# u/T recorded: 1.88234210326 0.00192438508133 after 9 integral calls.
# -------------
# Feeding in detuning/offset -72241440.3301 2.62068965517e-05 110 of 900 Evaluations
# u/T recorded: 1.89981017418 0.00196026726174 after 9 integral calls.
# -------------
# Feeding in detuning/offset -72241440.3301 2.75862068966e-05 111 of 900 Evaluations
# u/T recorded: 1.91791403952 0.0019978052273 after 9 integral calls.
# -------------
# Feeding in detuning/offset -72241440.3301 2.89655172414e-05 112 of 900 Evaluations
# u/T recorded: 1.93494750477 0.00203344880423 after 9 integral calls.
# -------------
# Feeding in detuning/offset -72241440.3301 3.03448275862e-05 113 of 900 Evaluations
# u/T recorded: 1.95174845839 0.00206891457238 after 9 integral calls.
# -------------
# Feeding in detuning/offset -72241440.3301 3.1724137931e-05 114 of 900 Evaluations
# u/T recorded: 1.96845445406 0.00210448391019 after 9 integral calls.
# -------------
# Feeding in detuning/offset -72241440.3301 3.31034482759e-05 115 of 900 Evaluations
# u/T recorded: 1.98488461182 0.00213976164296 after 9 integral calls.
# -------------
# Feeding in detuning/offset -72241440.3301 3.44827586207e-05 116 of 900 Evaluations
# u/T recorded: 2.00108062472 0.00217482362713 after 9 integral calls.
# -------------
# Feeding in detuning/offset -72241440.3301 3.58620689655e-05 117 of 900 Evaluations
# u/T recorded: 2.01700872022 0.00220958351036 after 10 integral calls.
# -------------
# Feeding in detuning/offset -72241440.3301 3.72413793103e-05 118 of 900 Evaluations
# u/T recorded: 2.03274151709 0.00224418772869 after 10 integral calls.
# -------------
# Feeding in detuning/offset -72241440.3301 3.86206896552e-05 119 of 900 Evaluations
# u/T recorded: 2.04824707527 0.00227855520597 after 10 integral calls.
# -------------
# Feeding in detuning/offset -72241440.3301 4e-05 120 of 900 Evaluations
# u/T recorded: 2.06355320236 0.00231273679081 after 10 integral calls.
# -------------
# Feeding in detuning/offset -69655231.249 0.0 121 of 900 Evaluations
# u/T recorded: 1.47004671206 0.00117370009219 after 7 integral calls.
# -------------
# Feeding in detuning/offset -69655231.249 1.37931034483e-06 122 of 900 Evaluations
# u/T recorded: 1.49120467816 0.00120772869072 after 9 integral calls.
# -------------
# Feeding in detuning/offset -69655231.249 2.75862068966e-06 123 of 900 Evaluations
# u/T recorded: 1.51267664448 0.0012427594424 after 8 integral calls.
# -------------
# Feeding in detuning/offset -69655231.249 4.13793103448e-06 124 of 900 Evaluations
# u/T recorded: 1.53427075248 0.00127849455 after 9 integral calls.
# -------------
# Feeding in detuning/offset -69655231.249 5.51724137931e-06 125 of 900 Evaluations
# u/T recorded: 1.55605825532 0.00131506304136 after 9 integral calls.
# -------------
# Feeding in detuning/offset -69655231.249 6.89655172414e-06 126 of 900 Evaluations
# u/T recorded: 1.57777883778 0.00135203247118 after 9 integral calls.
# -------------
# Feeding in detuning/offset -69655231.249 8.27586206897e-06 127 of 900 Evaluations
# u/T recorded: 1.59948182113 0.00138948379305 after 9 integral calls.
# -------------
# Feeding in detuning/offset -69655231.249 9.65517241379e-06 128 of 900 Evaluations
# u/T recorded: 1.62112684944 0.00142734469751 after 9 integral calls.
# -------------
# Feeding in detuning/offset -69655231.249 1.10344827586e-05 129 of 900 Evaluations
# u/T recorded: 1.64264907867 0.0014654953927 after 9 integral calls.
# -------------
# Feeding in detuning/offset -69655231.249 1.24137931034e-05 130 of 900 Evaluations
# u/T recorded: 1.6639826368 0.00150380820139 after 9 integral calls.
# -------------
# Feeding in detuning/offset -69655231.249 1.37931034483e-05 131 of 900 Evaluations
# u/T recorded: 1.68512982868 0.00154227422609 after 9 integral calls.
# -------------
# Feeding in detuning/offset -69655231.249 1.51724137931e-05 132 of 900 Evaluations
# u/T recorded: 1.70598580116 0.00158068631383 after 9 integral calls.
# -------------
# Feeding in detuning/offset -69655231.249 1.65517241379e-05 133 of 900 Evaluations
# u/T recorded: 1.7266516181 0.00161921421748 after 9 integral calls.
# -------------
# Feeding in detuning/offset -69655231.249 1.79310344828e-05 134 of 900 Evaluations
# u/T recorded: 1.74702005998 0.00165764165671 after 9 integral calls.
# -------------
# Feeding in detuning/offset -69655231.249 1.93103448276e-05 135 of 900 Evaluations
# u/T recorded: 1.76703901567 0.00169584886844 after 9 integral calls.
# -------------
# Feeding in detuning/offset -69655231.249 2.06896551724e-05 136 of 900 Evaluations
# u/T recorded: 1.7867439972 0.00173388197565 after 9 integral calls.
# -------------
# Feeding in detuning/offset -69655231.249 2.20689655172e-05 137 of 900 Evaluations
# u/T recorded: 1.80610785463 0.00177166755233 after 9 integral calls.
# -------------
# Feeding in detuning/offset -69655231.249 2.34482758621e-05 138 of 900 Evaluations
# u/T recorded: 1.8251858814 0.00180929369544 after 9 integral calls.
# -------------
# Feeding in detuning/offset -69655231.249 2.48275862069e-05 139 of 900 Evaluations
# u/T recorded: 1.84397381677 0.00184673410069 after 9 integral calls.
# -------------
# Feeding in detuning/offset -69655231.249 2.62068965517e-05 140 of 900 Evaluations
# u/T recorded: 1.86206024102 0.00188313876144 after 9 integral calls.
# -------------
# Feeding in detuning/offset -69655231.249 2.75862068966e-05 141 of 900 Evaluations
# u/T recorded: 1.88108402733 0.00192181358968 after 9 integral calls.
# -------------
# Feeding in detuning/offset -69655231.249 2.89655172414e-05 142 of 900 Evaluations
# u/T recorded: 1.89862196628 0.00195781598878 after 9 integral calls.
# -------------
# Feeding in detuning/offset -69655231.249 3.03448275862e-05 143 of 900 Evaluations
# u/T recorded: 1.91588539571 0.00199358116752 after 9 integral calls.
# -------------
# Feeding in detuning/offset -69655231.249 3.1724137931e-05 144 of 900 Evaluations
# u/T recorded: 1.93325231167 0.00202988738626 after 9 integral calls.
# -------------
# Feeding in detuning/offset -69655231.249 3.31034482759e-05 145 of 900 Evaluations
# u/T recorded: 1.95023134042 0.0020656994372 after 9 integral calls.
# -------------
# Feeding in detuning/offset -69655231.249 3.44827586207e-05 146 of 900 Evaluations
# u/T recorded: 1.96694976825 0.00210126780652 after 9 integral calls.
# -------------
# Feeding in detuning/offset -69655231.249 3.58620689655e-05 147 of 900 Evaluations
# u/T recorded: 1.98342168974 0.00213660866271 after 9 integral calls.
# -------------
# Feeding in detuning/offset -69655231.249 3.72413793103e-05 148 of 900 Evaluations
# u/T recorded: 1.99961499774 0.00217163903489 after 10 integral calls.
# -------------
# Feeding in detuning/offset -69655231.249 3.86206896552e-05 149 of 900 Evaluations
# u/T recorded: 2.01559633086 0.00220649011809 after 10 integral calls.
# -------------
# Feeding in detuning/offset -69655231.249 4e-05 150 of 900 Evaluations
# u/T recorded:

# %% [markdown]
# # Execute the code below after conducting a 2d scan in the cell above to make a heat map

# %%
print(Teq[5][10])
Teq[15][15]=.08
# Out:
# 0.00146137012834

# %%
#
# %matplotlib inline
import time
start_time = time.time()
import numpy as np
import scipy as sp
import scipy.optimize as opt
import scipy.integrate as integ
import matplotlib.pyplot as plt
from matplotlib.colors import BoundaryNorm
from matplotlib.ticker import MaxNLocator
#print(Teq)
#teqold=np.array(Teq)
#print(teqold)
plt.figure(figsize=(12, 10))
CS = plt.pcolor(doff, df, Teq)

CS=plt.xlabel('Laser Offset (um)')
CS=plt.ylabel('Laser Detuning (MHz)')
CS=plt.title('WY=30 um:Equilibrium Temperature')
plt.colorbar()
print("Minimum temperature:",Teq.min())
#plt.clabel(CS, inline=1, fontsize=10)
#plt.title('Simplest default with labels')
# Out:
# Minimum temperature: 0.000814378134867
